# %%
from git.repo.base import Repo
import git 
import os
import pandas as pd
import re

# %%
Students = {
            'Vitalii':'g1yk',
            'Kristina':'kikidesignnet',
            'Julian':'Kadus90',
            'Masaki':'mendosaurus',
            'Ignacio':'IgnacioBellomo',
            'Shahriyar':'shahryar102',
#             'Juan C':'jpcervera6',
            'Johnny':'jnguyen3436',
            'Gil':'gmsy',
            'Robbie':'robbiesanchez',
            'Saruit':'saruit0105',
            'Pradeepa':'pradeepa24',
            'Nicolas':'nbared',
            'Daphne':'daph3105',
            'Grant':'gdel21',
            'Avrahm':'avrahm',
            'Juan G':'JuanGrajales',
#             'Ironhack-Labs:': 'ironhack-labs'
           }

Labs = [
# 'https://github.com/ironhack-labs/lab-javascript-basic-algorithms',
#  'https://github.com/ironhack-labs/lab-css-recipes-clone',
#  'https://github.com/ironhack-labs/lab-javascript-functions-and-arrays',
#  'https://github.com/ironhack-labs/lab-css-instagram-clone',
#  'https://github.com/ironhack-labs/lab-javascript-clue',
#  'https://github.com/ironhack-labs/lab-css-spotify-clone',
#  'https://github.com/ironhack-labs/lab-javascript-greatest-movies',
#  'https://github.com/ironhack-labs/lab-css-flexbox-slack',
#  'https://github.com/ironhack-labs/lab-javascript-vikings',
#  'https://github.com/ironhack-labs/lab-dom-ironhack-cart',
#  'https://github.com/ironhack-labs/lab-dom-pizza-builder',
#  'https://github.com/ironhack-labs/lab-javascript-chronometer',
#  'https://github.com/ironhack-labs/lab-bootstrap-cloning-revera',
#  'https://github.com/ironhack-labs/lab-jquery-pizza-builder',
#  'https://github.com/ironhack-labs/lab-javascript-memory-game',
#  'https://github.com/ironhack-labs/lab-javascript-koans',
#  'https://github.com/ironhack-labs/lab-javascript-advanced-algorithms',
#  'https://github.com/ironhack-labs/lab-canvas-hangman',
#  'https://github.com/ironhack-labs/lab-canvas-race-car',
#  'https://github.com/ironhack-labs/lab-canvas-flappybirds',
#  'https://github.com/ironhack-labs/lab-es6-javascript-koans',
#  'https://github.com/ironhack-labs/lab-intro-node',
#  'https://github.com/ironhack-labs/lab-advance-querying-mongo',
#  'https://github.com/ironhack-labs/lab-express-basic-site',
#  'https://github.com/ironhack-labs/lab-ironbeers',
#  'https://github.com/ironhack-labs/lab-mongoose-recipes',
#  'https://github.com/ironhack-labs/lab-express-spotify',
#  'https://github.com/ironhack-labs/lab-express-cinema',
#  'https://github.com/ironhack-labs/lab-mongoose-movies',
#  'https://github.com/ironhack-labs/lab-express-basic-auth',
#  'https://github.com/ironhack-labs/lab-authentication-with-passport',
#  'https://github.com/ironhack-labs/lab-passport-roles',
#  'https://github.com/ironhack-labs/lab-coffee-and-books',
#  'https://github.com/ironhack-labs/lab-financial-data-graphing',
#  'https://github.com/ironhack-labs/lab-ajax-crud-characters',
#  'https://github.com/ironhack-labs/lab-nodemailer',
#  'https://github.com/ironhack-labs/lab-file-upload',
#  'https://github.com/ironhack-labs/lab-hello-ironhack',
 'https://github.com/ironhack-labs/lab-bulma-components',
#  'https://github.com/ironhack-labs/lab-react-ironcontacts',
#  'https://github.com/ironhack-labs/lab-react-training',
#  'https://github.com/ironhack-labs/lab-react-ironnutrition',
#  'https://github.com/ironhack-labs/lab-wiki-countries',
#  'https://github.com/ironhack-labs/lab-thinking-in-react',
#  'https://github.com/ironhack-labs/lab-react-ironbeers',
#  'https://github.com/ironhack-labs/lab-profile-app'
]

# %%
def CloneWeb(Dictionary=Students, Labs=Labs):
    
    
    
    
    for name, username in Dictionary.items(): 
        os.mkdir(name)
        path = os.getcwd() +'/'+ name 
        
        count = 0
        for lab in Labs: 
#             print("labs are being copied")
            try:
                count +=1 
                fork = lab.replace('ironhack-labs',username)
                lname = re.findall('lab-.*',lab)
                print(lname)
                print(fork)
                print(path)
                print(str(count))
#               Repo.clone_from(fork,path+'/'+str(count)+': '+lname)
                repo = Repo.clone_from(fork,path+"/"+str(count) + ") " +  lname[0], branch = "master")
                repo
                heads = repo.heads
                master = heads.master
                log = master.log()
                
                print(log)
#                 git_log = pd.read_csv(fork, compression="gzip")
#                 git_log.head()
#                 print(git_log.info())
                
                print(fork,path+'/' + lname, 'Successfully Cloned')
            except: 
                print(fork,path+"/"+str(count) + ") " +  lname[0] +  ' does not exist')
                pass
        
#         log = master.log()
#         print(log)

# %%
CloneWeb()
# Out:
# ['lab-bulma-components']
# https://github.com/nbared/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Nicolas
# 1
# [0000000000000000000000000000000000000000 494d8b70122c772b1caefe3aa74949fbd60eaca5 Nicholas Crispino <crispinonicky@gmail.com> 1573670629 -0500	clone: from https://github.com/nbared/lab-bulma-components
# ]
# ('https://github.com/nbared/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Nicolas/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/IgnacioBellomo/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Ignacio
# 1
# [0000000000000000000000000000000000000000 a76011d6b10c7e105d3b34b9493fee5e8a07d1f2 Nicholas Crispino <crispinonicky@gmail.com> 1573670630 -0500	clone: from https://github.com/IgnacioBellomo/lab-bulma-components
# ]
# ('https://github.com/IgnacioBellomo/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Ignacio/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/gmsy/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Gil
# 1
# [0000000000000000000000000000000000000000 59a8db5dba484df7a7318c56cbe4cd630c64ea4e Nicholas Crispino <crispinonicky@gmail.com> 1573670631 -0500	clone: from https://github.com/gmsy/lab-bulma-components
# ]
# ('https://github.com/gmsy/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Gil/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/jnguyen3436/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Johnny
# 1
# [0000000000000000000000000000000000000000 9d64b9765277f237b58771b79a96a7405e256740 Nicholas Crispino <crispinonicky@gmail.com> 1573670631 -0500	clone: from https://github.com/jnguyen3436/lab-bulma-components
# ]
# ('https://github.com/jnguyen3436/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Johnny/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/shahryar102/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Shahriyar
# 1
# [0000000000000000000000000000000000000000 9d64b9765277f237b58771b79a96a7405e256740 Nicholas Crispino <crispinonicky@gmail.com> 1573670632 -0500	clone: from https://github.com/shahryar102/lab-bulma-components
# ]
# ('https://github.com/shahryar102/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Shahriyar/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/gdel21/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Grant
# 1
# [0000000000000000000000000000000000000000 ea4b67216ca8d4a511f15d7b793f6393e4467fea Nicholas Crispino <crispinonicky@gmail.com> 1573670633 -0500	clone: from https://github.com/gdel21/lab-bulma-components
# ]
# ('https://github.com/gdel21/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Grant/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/mendosaurus/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Masaki
# 1
# [0000000000000000000000000000000000000000 ff09838b99a967b6db0d6f8a031dbf0a0d0e773d Nicholas Crispino <crispinonicky@gmail.com> 1573670633 -0500	clone: from https://github.com/mendosaurus/lab-bulma-components
# ]
# ('https://github.com/mendosaurus/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Masaki/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/Kadus90/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Julian
# 1
# [0000000000000000000000000000000000000000 32a803aea1a1cf9e47beb7cfd3ee502f98b34a64 Nicholas Crispino <crispinonicky@gmail.com> 1573670634 -0500	clone: from https://github.com/Kadus90/lab-bulma-components
# ]
# ('https://github.com/Kadus90/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Julian/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/JuanGrajales/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Juan G
# 1
# [0000000000000000000000000000000000000000 4bd457e64133eb67569a32e55ae9dc447902c17e Nicholas Crispino <crispinonicky@gmail.com> 1573670635 -0500	clone: from https://github.com/JuanGrajales/lab-bulma-components
# ]
# ('https://github.com/JuanGrajales/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Juan G/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/pradeepa24/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Pradeepa
# 1
# [0000000000000000000000000000000000000000 9d64b9765277f237b58771b79a96a7405e256740 Nicholas Crispino <crispinonicky@gmail.com> 1573670636 -0500	clone: from https://github.com/pradeepa24/lab-bulma-components
# ]
# ('https://github.com/pradeepa24/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Pradeepa/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/g1yk/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Vitalii
# 1
# [0000000000000000000000000000000000000000 2655aef675cf9b31aff15607ebd9d588b3f68cb9 Nicholas Crispino <crispinonicky@gmail.com> 1573670636 -0500	clone: from https://github.com/g1yk/lab-bulma-components
# ]
# ('https://github.com/g1yk/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Vitalii/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/avrahm/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Avrahm
# 1
# [0000000000000000000000000000000000000000 264dc90b09ed5fb0492060c2fea6c5d7890b83fb Nicholas Crispino <crispinonicky@gmail.com> 1573670637 -0500	clone: from https://github.com/avrahm/lab-bulma-components
# ]
# ('https://github.com/avrahm/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Avrahm/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/kikidesignnet/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Kristina
# 1
# [0000000000000000000000000000000000000000 baa065f97c31d881bf96d2c3a6c403a787ee1bcb Nicholas Crispino <crispinonicky@gmail.com> 1573670637 -0500	clone: from https://github.com/kikidesignnet/lab-bulma-components
# ]
# ('https://github.com/kikidesignnet/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Kristina/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/daph3105/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Daphne
# 1
# [0000000000000000000000000000000000000000 9d64b9765277f237b58771b79a96a7405e256740 Nicholas Crispino <crispinonicky@gmail.com> 1573670638 -0500	clone: from https://github.com/daph3105/lab-bulma-components
# ]
# ('https://github.com/daph3105/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Daphne/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/saruit0105/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Saruit
# 1
# [0000000000000000000000000000000000000000 45fe5b24139341e81205bdc66edaa949f896d246 Nicholas Crispino <crispinonicky@gmail.com> 1573670639 -0500	clone: from https://github.com/saruit0105/lab-bulma-components
# ]
# ('https://github.com/saruit0105/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Saruit/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/jpcervera6/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Juan C
# 1
# [0000000000000000000000000000000000000000 9d64b9765277f237b58771b79a96a7405e256740 Nicholas Crispino <crispinonicky@gmail.com> 1573670639 -0500	clone: from https://github.com/jpcervera6/lab-bulma-components
# ]
# ('https://github.com/jpcervera6/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Juan C/1) lab-bulma-components does not exist')
# ['lab-bulma-components']
# https://github.com/robbiesanchez/lab-bulma-components
# /Users/nicholas_crispino/Desktop/TA/script-for-labs/Robbie
# 1
# [0000000000000000000000000000000000000000 9d64b9765277f237b58771b79a96a7405e256740 Nicholas Crispino <crispinonicky@gmail.com> 1573670640 -0500	clone: from https://github.com/robbiesanchez/lab-bulma-components
# ]
# ('https://github.com/robbiesanchez/lab-bulma-components', '/Users/nicholas_crispino/Desktop/TA/script-for-labs/Robbie/1) lab-bulma-components does not exist')
